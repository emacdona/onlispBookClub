# %%
plot([sin(x), cos(x), tan(x)], -2*pi, 2*pi, ymin=-2, ymax=2)
# Out:
# verbose 0 (3791: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 168 points.
# verbose 0 (3791: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 4 graphics primitives

# %%
plot([arccos(x), arcsin(x)], -1, 1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(arctan(x), -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive
